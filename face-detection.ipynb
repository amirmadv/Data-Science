# %% [markdown]
# <a href="https://colab.research.google.com/github/amirmadv/Data-Science/blob/master/face-detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt

# %%
import cv2

# %%
image =cv2.imread("adel.jpg")

# %%
plt.imshow(image)

# %%
image =cv2.cvtColor(image , cv2.COLOR_BGR2RGB)

# %%
model = cv2.CascadeClassifier("model.xml")

# %%
face = model.detectMultiScale(image)

# %%
image.shape
# Out:
# (250, 300, 3)

# %%
x = face[0][0]
y = face[0][1]
a = face[0][2]
b = face[0][3]

# %%
image = cv2.rectangle(image , (x,y),(x+a,y+b),(0,255,0), 4 )

# %%
plt.imshow(image)
